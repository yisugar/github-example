# %% [markdown]
# # Import Libraries

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# # Foursuare Credentials

# %%
CLIENT_ID = 'GEOB3Q4RTF3RYS1WW0YUO1K1TH2S3JACF40KFZGGILESXARV'
CLIENT_SECRET = 'DZT1HG4VZQFFQVQRZLIVQ25HFWJAEAWIEKKO2AYGE1HHOB3J'
VERSION = '20200212' 

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: GEOB3Q4RTF3RYS1WW0YUO1K1TH2S3JACF40KFZGGILESXARV
# CLIENT_SECRET:DZT1HG4VZQFFQVQRZLIVQ25HFWJAEAWIEKKO2AYGE1HHOB3J

# %% [markdown]
# # Define city and its latitude & longitude

# %%
city = 'Philadelphia'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 39.9527237 -75.1635262

# %% [markdown]
# # Search for Hotels

# %%
# search for hotels
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}'\
.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=GEOB3Q4RTF3RYS1WW0YUO1K1TH2S3JACF40KFZGGILESXARV&client_secret=DZT1HG4VZQFFQVQRZLIVQ25HFWJAEAWIEKKO2AYGE1HHOB3J&ll=39.9527237,-75.1635262&v=20200212&query=Hotel&radius=500'

# %%
# Send the GET Request and examine the results
results = requests.get(url).json()
#results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...         NaN
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...         NaN
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...         NaN
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...         NaN
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...     1523643
#
#                delivery.provider.icon.name  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4  /delivery_provider_grubhub_20180129.png
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1                                       NaN                          NaN
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
#
#   delivery.provider.name                                       delivery.url  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                grubhub  https://www.grubhub.com/restaurant/basement-at...
#
#    hasPerk                        id  location.address location.cc  \
# 0    False  5d30fd7d844dd800083fe25c   21 N Juniper St          US
# 1    False  4a0bf2c3f964a5200e751fe3    1200 Market St          US
# 2    False  4afb8f59f964a520a11e22e3     117 S 17th St          US
# 3    False  4aba8dbff964a520d78120e3  1628 Chestnut St          US
# 4    False  49d57ecef964a520985c1fe3    200 S Broad St          US
#
#   location.city location.country location.crossStreet  location.distance  \
# 0  Philadelphia    United States                  NaN                150
# 1  Philadelphia    United States                  NaN                311
# 2  Philadelphia    United States         at Sansom St                485
# 3  Philadelphia    United States          at 17th St.                444
# 4  Philadelphia    United States                  NaN                424
#
#                            location.formattedAddress  \
# 0  [21 N Juniper St, Philadelphia, PA 19107, Unit...
# 1  [1200 Market St, Philadelphia, PA 19107, Unite...
# 2  [117 S 17th St (at Sansom St), Philadelphia, P...
# 3  [1628 Chestnut St (at 17th St.), Philadelphia,...
# 4  [200 S Broad St, Philadelphia, PA 19102, Unite...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 39.953016, 'lng':...     39.953016
# 1  [{'label': 'display', 'lat': 39.95141891142559...     39.951419
# 2  [{'label': 'display', 'lat': 39.950809, 'lng':...     39.950809
# 3  [{'label': 'display', 'lat': 39.95130770193616...     39.951308
# 4  [{'label': 'display', 'lat': 39.94905, 'lng': ...     39.949050
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -75.161805                   NaN               19107             PA
# 1    -75.160303                   NaN               19107             PA
# 2    -75.168642                   NaN               19103             PA
# 3    -75.168396                   NaN               19103             PA
# 4    -75.164850                   NaN               19102             PA
#
#                                   name    referralId venuePage.id
# 0                     The Notary Hotel  v-1581626365          NaN
# 1             Loews Philadelphia Hotel  v-1581626365     34285545
# 2   Kimpton Hotel Palomar Philadelphia  v-1581626365     44568656
# 3  Club Quarters Hotel in Philadelphia  v-1581626365          NaN
# 4                   The Bellevue Hotel  v-1581626365          NaN

# %% [markdown]
# # Clean Hotel Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                                   name categories           address  cc  \
# 0                     The Notary Hotel      Hotel   21 N Juniper St  US
# 1             Loews Philadelphia Hotel      Hotel    1200 Market St  US
# 2   Kimpton Hotel Palomar Philadelphia      Hotel     117 S 17th St  US
# 3  Club Quarters Hotel in Philadelphia      Hotel  1628 Chestnut St  US
# 4                   The Bellevue Hotel      Hotel    200 S Broad St  US
#
#            city        country   crossStreet  distance  \
# 0  Philadelphia  United States           NaN       150
# 1  Philadelphia  United States           NaN       311
# 2  Philadelphia  United States  at Sansom St       485
# 3  Philadelphia  United States   at 17th St.       444
# 4  Philadelphia  United States           NaN       424
#
#                                     formattedAddress  \
# 0  [21 N Juniper St, Philadelphia, PA 19107, Unit...
# 1  [1200 Market St, Philadelphia, PA 19107, Unite...
# 2  [117 S 17th St (at Sansom St), Philadelphia, P...
# 3  [1628 Chestnut St (at 17th St.), Philadelphia,...
# 4  [200 S Broad St, Philadelphia, PA 19102, Unite...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 39.953016, 'lng':...  39.953016 -75.161805
# 1  [{'label': 'display', 'lat': 39.95141891142559...  39.951419 -75.160303
# 2  [{'label': 'display', 'lat': 39.950809, 'lng':...  39.950809 -75.168642
# 3  [{'label': 'display', 'lat': 39.95130770193616...  39.951308 -75.168396
# 4  [{'label': 'display', 'lat': 39.94905, 'lng': ...  39.949050 -75.164850
#
#   neighborhood postalCode state                        id
# 0          NaN      19107    PA  5d30fd7d844dd800083fe25c
# 1          NaN      19107    PA  4a0bf2c3f964a5200e751fe3
# 2          NaN      19103    PA  4afb8f59f964a520a11e22e3
# 3          NaN      19103    PA  4aba8dbff964a520d78120e3
# 4          NaN      19102    PA  49d57ecef964a520985c1fe3

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2
# Out:
#                                                name           categories  \
# 0                                  The Notary Hotel                Hotel
# 1                          Loews Philadelphia Hotel                Hotel
# 2                Kimpton Hotel Palomar Philadelphia                Hotel
# 3               Club Quarters Hotel in Philadelphia                Hotel
# 4                                The Bellevue Hotel                Hotel
# 5   Cambria Hotel Philadelphia Downtown Center City                Hotel
# 6                             The Independent Hotel                Hotel
# 7                                Harleysville hotel  American Restaurant
# 8                            Philadelphia 201 Hotel                Hotel
# 9                                  Hotel California                 None
# 10    The Solstice Room at Loews Philadelphia Hotel                Hotel
# 11                                    Hotel Wheeler      Other Nightlife
# 12                     Hotel Palomar Fitness Center                  Gym
# 13                                 Loews Hotel Pool           Hotel Pool
# 14                      Loews Hotel Washington Room          Event Space
# 15                        Paris Bar - Sofitel Hotel                 Café
# 16                                       Hotel Pool                 Pool
# 17                                        Hotel MVT                 None
# 18                   Philadelphia Marriott Downtown                Hotel
# 19                       Franklin Room Westin Hotel         Meeting Room
# 20                              Bingham House Hotel                Hotel
# 21                    Morrison Hotel at the windsor     Basketball Court
# 22                      the Independence Hotel 1234             Building
# 23                   The Ritz-Carlton, Philadelphia                Hotel
# 24                      Latham Hotel Fitness Center   Athletics & Sports
# 25          Sonesta Philadelphia Rittenhouse Square                Hotel
# 26                          The Westin Philadelphia                Hotel
# 27                         Le Méridien Philadelphia                Hotel
# 28         Holiday Inn Express Philadelphia-Midtown                Hotel
# 29                                Hilton Garden Inn                Hotel
#
#                                               address        lat        lng  \
# 0                                     21 N Juniper St  39.953016 -75.161805
# 1                                      1200 Market St  39.951419 -75.160303
# 2                                       117 S 17th St  39.950809 -75.168642
# 3                                    1628 Chestnut St  39.951308 -75.168396
# 4                                      200 S Broad St  39.949050 -75.164850
# 5                                      219 S Broad St  39.948627 -75.164198
# 6                                      1234 Locust St  39.947781 -75.162146
# 7                                         Main street  39.954462 -75.162617
# 8                                                 NaN  39.956928 -75.167478
# 9                                                 NaN  39.951400 -75.165598
# 10                                     1200 Market St  39.951797 -75.159876
# 11                                                NaN  39.951060 -75.165620
# 12                                                NaN  39.950739 -75.168695
# 13                                                NaN  39.951680 -75.160164
# 14                                                NaN  39.950569 -75.161003
# 15                                                NaN  39.950848 -75.169069
# 16                                                NaN  39.956084 -75.168199
# 17                                                NaN  39.947798 -75.160763
# 18  1201 Market Street, (Guest Entrance At 1200 Fi...  39.952604 -75.160625
# 19                                       99 S 17th St  39.951601 -75.168521
# 20                             11th and Market Street  39.951713 -75.158306
# 21                        1700 Benjamin Franklin Pkwy  39.955628 -75.167888
# 22                                     1234 Locust St  39.948139 -75.162128
# 23                              10 Avenue of the Arts  39.951446 -75.164149
# 24                                                NaN  39.950050 -75.168957
# 25                                     1800 Market St  39.952834 -75.170345
# 26                                       99 S 17th St  39.952112 -75.168492
# 27                                       1421 Arch St  39.954867 -75.164141
# 28                                     1305 Walnut St  39.949282 -75.162557
# 29                                       1100 Arch St  39.953572 -75.158085
#
#    postalCode         state
# 0       19107            PA
# 1       19107            PA
# 2       19103            PA
# 3       19103            PA
# 4       19102            PA
# 5       19107            PA
# 6       19107            PA
# 7         NaN            PA
# 8       19103            PA
# 9         NaN  Pennsylvania
# 10      19107            PA
# 11        NaN            PA
# 12        NaN            PA
# 13      19107            PA
# 14      19107            PA
# 15      19103            PA
# 16      19103            PA
# 17      19107            PA
# 18      19107            PA
# 19      19103            PA
# 20      19107            PA
# 21      19103            PA
# 22      19107            PA
# 23      19102            PA
# 24        NaN            PA
# 25      19103            PA
# 26      19103            PA
# 27      19102            PA
# 28      19107            PA
# 29      19107            PA

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                                                name        categories  \
# 0                                  The Notary Hotel             Hotel
# 1                          Loews Philadelphia Hotel             Hotel
# 2                Kimpton Hotel Palomar Philadelphia             Hotel
# 3               Club Quarters Hotel in Philadelphia             Hotel
# 4                                The Bellevue Hotel             Hotel
# 5   Cambria Hotel Philadelphia Downtown Center City             Hotel
# 6                             The Independent Hotel             Hotel
# 10    The Solstice Room at Loews Philadelphia Hotel             Hotel
# 18                   Philadelphia Marriott Downtown             Hotel
# 19                       Franklin Room Westin Hotel      Meeting Room
# 20                              Bingham House Hotel             Hotel
# 21                    Morrison Hotel at the windsor  Basketball Court
# 22                      the Independence Hotel 1234          Building
# 23                   The Ritz-Carlton, Philadelphia             Hotel
# 25          Sonesta Philadelphia Rittenhouse Square             Hotel
# 26                          The Westin Philadelphia             Hotel
# 27                         Le Méridien Philadelphia             Hotel
# 28         Holiday Inn Express Philadelphia-Midtown             Hotel
# 29                                Hilton Garden Inn             Hotel
#
#                                               address        lat        lng  \
# 0                                     21 N Juniper St  39.953016 -75.161805
# 1                                      1200 Market St  39.951419 -75.160303
# 2                                       117 S 17th St  39.950809 -75.168642
# 3                                    1628 Chestnut St  39.951308 -75.168396
# 4                                      200 S Broad St  39.949050 -75.164850
# 5                                      219 S Broad St  39.948627 -75.164198
# 6                                      1234 Locust St  39.947781 -75.162146
# 10                                     1200 Market St  39.951797 -75.159876
# 18  1201 Market Street, (Guest Entrance At 1200 Fi...  39.952604 -75.160625
# 19                                       99 S 17th St  39.951601 -75.168521
# 20                             11th and Market Street  39.951713 -75.158306
# 21                        1700 Benjamin Franklin Pkwy  39.955628 -75.167888
# 22                                     1234 Locust St  39.948139 -75.162128
# 23                              10 Avenue of the Arts  39.951446 -75.164149
# 25                                     1800 Market St  39.952834 -75.170345
# 26                                       99 S 17th St  39.952112 -75.168492
# 27                                       1421 Arch St  39.954867 -75.164141
# 28                                     1305 Walnut St  39.949282 -75.162557
# 29                                       1100 Arch St  39.953572 -75.158085
#
#    postalCode state
# 0       19107    PA
# 1       19107    PA
# 2       19103    PA
# 3       19103    PA
# 4       19102    PA
# 5       19107    PA
# 6       19107    PA
# 10      19107    PA
# 18      19107    PA
# 19      19103    PA
# 20      19107    PA
# 21      19103    PA
# 22      19107    PA
# 23      19102    PA
# 25      19103    PA
# 26      19103    PA
# 27      19102    PA
# 28      19107    PA
# 29      19107    PA

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                                name categories  \
# 0                                  The Notary Hotel      Hotel
# 1                          Loews Philadelphia Hotel      Hotel
# 2                Kimpton Hotel Palomar Philadelphia      Hotel
# 3               Club Quarters Hotel in Philadelphia      Hotel
# 4                                The Bellevue Hotel      Hotel
# 5   Cambria Hotel Philadelphia Downtown Center City      Hotel
# 6                             The Independent Hotel      Hotel
# 10    The Solstice Room at Loews Philadelphia Hotel      Hotel
# 18                   Philadelphia Marriott Downtown      Hotel
# 20                              Bingham House Hotel      Hotel
# 23                   The Ritz-Carlton, Philadelphia      Hotel
# 25          Sonesta Philadelphia Rittenhouse Square      Hotel
# 26                          The Westin Philadelphia      Hotel
# 27                         Le Méridien Philadelphia      Hotel
# 28         Holiday Inn Express Philadelphia-Midtown      Hotel
# 29                                Hilton Garden Inn      Hotel
#
#                                               address        lat        lng  \
# 0                                     21 N Juniper St  39.953016 -75.161805
# 1                                      1200 Market St  39.951419 -75.160303
# 2                                       117 S 17th St  39.950809 -75.168642
# 3                                    1628 Chestnut St  39.951308 -75.168396
# 4                                      200 S Broad St  39.949050 -75.164850
# 5                                      219 S Broad St  39.948627 -75.164198
# 6                                      1234 Locust St  39.947781 -75.162146
# 10                                     1200 Market St  39.951797 -75.159876
# 18  1201 Market Street, (Guest Entrance At 1200 Fi...  39.952604 -75.160625
# 20                             11th and Market Street  39.951713 -75.158306
# 23                              10 Avenue of the Arts  39.951446 -75.164149
# 25                                     1800 Market St  39.952834 -75.170345
# 26                                       99 S 17th St  39.952112 -75.168492
# 27                                       1421 Arch St  39.954867 -75.164141
# 28                                     1305 Walnut St  39.949282 -75.162557
# 29                                       1100 Arch St  39.953572 -75.158085
#
#    postalCode state
# 0       19107    PA
# 1       19107    PA
# 2       19103    PA
# 3       19103    PA
# 4       19102    PA
# 5       19107    PA
# 6       19107    PA
# 10      19107    PA
# 18      19107    PA
# 20      19107    PA
# 23      19102    PA
# 25      19103    PA
# 26      19103    PA
# 27      19102    PA
# 28      19107    PA
# 29      19107    PA

# %%
# delete rows which has duplicate hotel's name
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                                name categories  \
# 0                                  The Notary Hotel      Hotel
# 1                          Loews Philadelphia Hotel      Hotel
# 2                Kimpton Hotel Palomar Philadelphia      Hotel
# 3               Club Quarters Hotel in Philadelphia      Hotel
# 4                                The Bellevue Hotel      Hotel
# 5   Cambria Hotel Philadelphia Downtown Center City      Hotel
# 6                             The Independent Hotel      Hotel
# 10    The Solstice Room at Loews Philadelphia Hotel      Hotel
# 18                   Philadelphia Marriott Downtown      Hotel
# 20                              Bingham House Hotel      Hotel
# 23                   The Ritz-Carlton, Philadelphia      Hotel
# 25          Sonesta Philadelphia Rittenhouse Square      Hotel
# 26                          The Westin Philadelphia      Hotel
# 27                         Le Méridien Philadelphia      Hotel
# 28         Holiday Inn Express Philadelphia-Midtown      Hotel
# 29                                Hilton Garden Inn      Hotel
#
#                                               address        lat        lng  \
# 0                                     21 N Juniper St  39.953016 -75.161805
# 1                                      1200 Market St  39.951419 -75.160303
# 2                                       117 S 17th St  39.950809 -75.168642
# 3                                    1628 Chestnut St  39.951308 -75.168396
# 4                                      200 S Broad St  39.949050 -75.164850
# 5                                      219 S Broad St  39.948627 -75.164198
# 6                                      1234 Locust St  39.947781 -75.162146
# 10                                     1200 Market St  39.951797 -75.159876
# 18  1201 Market Street, (Guest Entrance At 1200 Fi...  39.952604 -75.160625
# 20                             11th and Market Street  39.951713 -75.158306
# 23                              10 Avenue of the Arts  39.951446 -75.164149
# 25                                     1800 Market St  39.952834 -75.170345
# 26                                       99 S 17th St  39.952112 -75.168492
# 27                                       1421 Arch St  39.954867 -75.164141
# 28                                     1305 Walnut St  39.949282 -75.162557
# 29                                       1100 Arch St  39.953572 -75.158085
#
#    postalCode state
# 0       19107    PA
# 1       19107    PA
# 2       19103    PA
# 3       19103    PA
# 4       19102    PA
# 5       19107    PA
# 6       19107    PA
# 10      19107    PA
# 18      19107    PA
# 20      19107    PA
# 23      19102    PA
# 25      19103    PA
# 26      19103    PA
# 27      19102    PA
# 28      19107    PA
# 29      19107    PA

# %% [markdown]
# # Search for Grocery Store

# %%
search_query = 'grocery store'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}'\
.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius,)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=GEOB3Q4RTF3RYS1WW0YUO1K1TH2S3JACF40KFZGGILESXARV&client_secret=DZT1HG4VZQFFQVQRZLIVQ25HFWJAEAWIEKKO2AYGE1HHOB3J&ll=39.9527237,-75.1635262&v=20200212&query=grocery store&radius=10000'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()
#presults

# %%
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
grocerystore_dataframe = json_normalize(venues)
grocerystore_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...    False
# 1  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...    False
# 2  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d1f9941735', 'name': 'F...    False
# 4  [{'id': '4bf58dd8d48988d146941735', 'name': 'D...    False
#
#                          id             location.address location.cc  \
# 0  4b61db1ef964a52057272ae3               1227 S 18th St          US
# 1  4da8cef80cb6a89c624731bd  2200 Benjamin Franklin Pkwy          US
# 2  55cb5f4f498ea925f1c61718                          NaN          US
# 3  4b5a21d7f964a5203daf28e3              1500 S Broad St          US
# 4  572f6a31498e66d843d0c2d6                          NaN          US
#
#   location.city location.country location.crossStreet  location.distance  \
# 0  Philadelphia    United States  btw 18th and Latona               2071
# 1  Philadelphia    United States                  NaN               1217
# 2  Philadelphia    United States                  NaN               1699
# 3  Philadelphia    United States   15th and Dickinson               2381
# 4  Philadelphia    United States                  NaN               1981
#
#                            location.formattedAddress  \
# 0  [1227 S 18th St (btw 18th and Latona), Philade...
# 1  [2200 Benjamin Franklin Pkwy, Philadelphia, PA...
# 2                  [Philadelphia, PA, United States]
# 3  [1500 S Broad St (15th and Dickinson), Philade...
# 4                  [Philadelphia, PA, United States]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 39.93584892968741...     39.935849
# 1  [{'label': 'display', 'lat': 39.958787, 'lng':...     39.958787
# 2  [{'label': 'display', 'lat': 39.93849786664969...     39.938498
# 3  [{'label': 'display', 'lat': 39.93167299999999...     39.931673
# 4  [{'label': 'display', 'lat': 39.934977, 'lng':...     39.934977
#
#    location.lng location.postalCode location.state                     name  \
# 0    -75.173754               19146             PA  Fernandez Grocery Store
# 1    -75.175407               19130             PA            Grocery Store
# 2    -75.156285                 NaN             PA    Lucky 7 Grocery Store
# 3    -75.168482               19146             PA         88 Grocery Store
# 4    -75.161750                 NaN             PA      Edith Grocery Store
#
#      referralId
# 0  v-1581626574
# 1  v-1581626574
# 2  v-1581626574
# 3  v-1581626574
# 4  v-1581626574

# %% [markdown]
# # Clean Park Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
grocerystore_clean_columns = ['name', 'categories'] + [col for col in grocerystore_dataframe.columns if col.startswith('location.')]+ ['id']
clean_grocerystore_dataframe = grocerystore_dataframe.loc[:,grocerystore_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_grocerystore_dataframe['categories'] = clean_grocerystore_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_grocerystore_dataframe.columns = [column.split('.')[-1] for column in clean_grocerystore_dataframe.columns]

clean_grocerystore_dataframe.head()
# Out:
#                       name         categories                      address  \
# 0  Fernandez Grocery Store      Grocery Store               1227 S 18th St
# 1            Grocery Store      Grocery Store  2200 Benjamin Franklin Pkwy
# 2    Lucky 7 Grocery Store  Convenience Store                          NaN
# 3         88 Grocery Store  Food & Drink Shop              1500 S Broad St
# 4      Edith Grocery Store      Deli / Bodega                          NaN
#
#    cc          city        country          crossStreet  distance  \
# 0  US  Philadelphia  United States  btw 18th and Latona      2071
# 1  US  Philadelphia  United States                  NaN      1217
# 2  US  Philadelphia  United States                  NaN      1699
# 3  US  Philadelphia  United States   15th and Dickinson      2381
# 4  US  Philadelphia  United States                  NaN      1981
#
#                                     formattedAddress  \
# 0  [1227 S 18th St (btw 18th and Latona), Philade...
# 1  [2200 Benjamin Franklin Pkwy, Philadelphia, PA...
# 2                  [Philadelphia, PA, United States]
# 3  [1500 S Broad St (15th and Dickinson), Philade...
# 4                  [Philadelphia, PA, United States]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 39.93584892968741...  39.935849 -75.173754
# 1  [{'label': 'display', 'lat': 39.958787, 'lng':...  39.958787 -75.175407
# 2  [{'label': 'display', 'lat': 39.93849786664969...  39.938498 -75.156285
# 3  [{'label': 'display', 'lat': 39.93167299999999...  39.931673 -75.168482
# 4  [{'label': 'display', 'lat': 39.934977, 'lng':...  39.934977 -75.161750
#
#   postalCode state                        id
# 0      19146    PA  4b61db1ef964a52057272ae3
# 1      19130    PA  4da8cef80cb6a89c624731bd
# 2        NaN    PA  55cb5f4f498ea925f1c61718
# 3      19146    PA  4b5a21d7f964a5203daf28e3
# 4        NaN    PA  572f6a31498e66d843d0c2d6

# %%
# delete unnecessary columns
clean_grocerystore_dataframe2= clean_grocerystore_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_grocerystore_dataframe2
# Out:
#                                  name                 categories  \
# 0             Fernandez Grocery Store              Grocery Store
# 1                       Grocery Store              Grocery Store
# 2               Lucky 7 Grocery Store          Convenience Store
# 3                    88 Grocery Store          Food & Drink Shop
# 4                 Edith Grocery Store              Deli / Bodega
# 5                  Luna Grocery Store          Convenience Store
# 6                 L. M. Grocery Store          Convenience Store
# 7   Eak Meng: Cambodian Grocery Store              Grocery Store
# 8                   Sun Grocery Store          Convenience Store
# 9                 Lin's Grocery Store              Grocery Store
# 10            Jerusalem Grocery Store  Middle Eastern Restaurant
# 11               Freddy Grocery Store              Deli / Bodega
# 12        10th & Snyder Grocery Store              Grocery Store
# 13             Venuti's Grocery Store              Grocery Store
# 14                     Grocery Stores         Mexican Restaurant
# 15                 Anna Grocery Store              Deli / Bodega
# 16               Andrew Grocery Store              Deli / Bodega
# 17               Tamyra Grocery Store              Deli / Bodega
# 18                fresh grocery store                     Market
# 19            Freddie's Grocery Store              Deli / Bodega
# 20            Albertina Grocery Store          Convenience Store
# 21               Justin grocery store          Convenience Store
# 22                   Jr Grocery Store              Grocery Store
# 23                Josue grocery store              Grocery Store
# 24              Evelean grocery store              Grocery Store
# 25             Delainny Grocery Store              Deli / Bodega
# 26            Alejandro Grocery Store              Deli / Bodega
# 27            Albertina Grocery Store          Convenience Store
# 28   Michael's deli and grocery store              Grocery Store
# 29       Deca Pizza and Grocery Store                Pizza Place
#
#                         address        lat        lng postalCode         state
# 0                1227 S 18th St  39.935849 -75.173754      19146            PA
# 1   2200 Benjamin Franklin Pkwy  39.958787 -75.175407      19130            PA
# 2                           NaN  39.938498 -75.156285        NaN            PA
# 3               1500 S Broad St  39.931673 -75.168482      19146            PA
# 4                           NaN  39.934977 -75.161750        NaN            PA
# 5                           NaN  39.934820 -75.161963        NaN  Pennsylvania
# 6                           NaN  39.933393 -75.162310        NaN  Pennsylvania
# 7                    7th Street  39.922412 -75.158218      19148            PA
# 8                           NaN  39.924047 -75.175087        NaN            PA
# 9                           NaN  39.922664 -75.152295        NaN  Pennsylvania
# 10             115 W Girard Ave  39.969112 -75.136764      19123            PA
# 11                          NaN  39.969006 -75.192947      19104            PA
# 12              1000 Snyder Ave  39.923217 -75.162336      19148            PA
# 13              South Camac St.  39.916994 -75.168181      19148            PA
# 14                  17th Street  39.964811 -75.165907      19130            PA
# 15               2200 S 20th St  39.924285 -75.179552      19145            PA
# 16            400 McKean Street  39.923715 -75.153132      19146            PA
# 17            1770 N Mascher St  39.977352 -75.136037      19122            PA
# 18                          NaN  39.940827 -75.219814        NaN            PA
# 19                  625 Avon St  39.937223 -75.122921      08103            NJ
# 20                          NaN  39.986481 -75.140594      19133            PA
# 21                          NaN  39.987226 -75.139314        NaN            PA
# 22                          NaN  39.990149 -75.140768      19133            PA
# 23                          NaN  39.989082 -75.138870        NaN            PA
# 24                          NaN  39.990604 -75.142799        NaN            PA
# 25                          NaN  39.936836 -75.113907        NaN    New Jersey
# 26         3000 W Cumberland St  39.994268 -75.181085      19132            PA
# 27                          NaN  39.989409 -75.134218      19133            PA
# 28                          NaN  39.994663 -75.147026        NaN            PA
# 29         3319 W Cumberland St  39.995022 -75.186327      19132            PA

# %%
# delete rows with none values
clean_grocerystore_dataframe3 = clean_grocerystore_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_grocerystore_dataframe3
# Out:
#                                  name                 categories  \
# 0             Fernandez Grocery Store              Grocery Store
# 1                       Grocery Store              Grocery Store
# 3                    88 Grocery Store          Food & Drink Shop
# 7   Eak Meng: Cambodian Grocery Store              Grocery Store
# 10            Jerusalem Grocery Store  Middle Eastern Restaurant
# 12        10th & Snyder Grocery Store              Grocery Store
# 13             Venuti's Grocery Store              Grocery Store
# 14                     Grocery Stores         Mexican Restaurant
# 15                 Anna Grocery Store              Deli / Bodega
# 16               Andrew Grocery Store              Deli / Bodega
# 17               Tamyra Grocery Store              Deli / Bodega
# 19            Freddie's Grocery Store              Deli / Bodega
# 26            Alejandro Grocery Store              Deli / Bodega
# 29       Deca Pizza and Grocery Store                Pizza Place
#
#                         address        lat        lng postalCode state
# 0                1227 S 18th St  39.935849 -75.173754      19146    PA
# 1   2200 Benjamin Franklin Pkwy  39.958787 -75.175407      19130    PA
# 3               1500 S Broad St  39.931673 -75.168482      19146    PA
# 7                    7th Street  39.922412 -75.158218      19148    PA
# 10             115 W Girard Ave  39.969112 -75.136764      19123    PA
# 12              1000 Snyder Ave  39.923217 -75.162336      19148    PA
# 13              South Camac St.  39.916994 -75.168181      19148    PA
# 14                  17th Street  39.964811 -75.165907      19130    PA
# 15               2200 S 20th St  39.924285 -75.179552      19145    PA
# 16            400 McKean Street  39.923715 -75.153132      19146    PA
# 17            1770 N Mascher St  39.977352 -75.136037      19122    PA
# 19                  625 Avon St  39.937223 -75.122921      08103    NJ
# 26         3000 W Cumberland St  39.994268 -75.181085      19132    PA
# 29         3319 W Cumberland St  39.995022 -75.186327      19132    PA

# %% [markdown]
# # Search for Restaurants

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=GEOB3Q4RTF3RYS1WW0YUO1K1TH2S3JACF40KFZGGILESXARV&client_secret=DZT1HG4VZQFFQVQRZLIVQ25HFWJAEAWIEKKO2AYGE1HHOB3J&ll=39.9527237,-75.1635262&v=20200212&query=Restaurant&radius=10000'

# %%
# Send the GET Request and examine the results
Rresults = requests.get(url).json()
#Rresults

# %%
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...         NaN
# 1  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...      559902
# 2  [{'id': '4bf58dd8d48988d147941735', 'name': 'D...      365418
# 3  [{'id': '4bf58dd8d48988d11d941735', 'name': 'S...         NaN
# 4  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...      994563
#
#                delivery.provider.icon.name  \
# 0                                      NaN
# 1  /delivery_provider_grubhub_20180129.png
# 2  /delivery_provider_grubhub_20180129.png
# 3                                      NaN
# 4  /delivery_provider_grubhub_20180129.png
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 2  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 3                                       NaN                          NaN
# 4  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
#
#   delivery.provider.name                                       delivery.url  \
# 0                    NaN                                                NaN
# 1                grubhub  https://www.grubhub.com/restaurant/e-mei-resta...
# 2                grubhub  https://www.grubhub.com/restaurant/continental...
# 3                    NaN                                                NaN
# 4                grubhub  https://www.grubhub.com/restaurant/vietnam-exp...
#
#    hasPerk                        id location.address location.cc  \
# 0    False  40b28c80f964a52033f91ee3   1116 Walnut St          US
# 1    False  4d85387c61676dcb586b85e4      915 Arch St          US
# 2    False  4a620924f964a520dfc21fe3     28 S 18th St          US
# 3    False  49f124b5f964a52090691fe3  39-41 S 19th St          US
# 4    False  4d3cb0f98edf3704b8c2b2a5    221 N 11th St          US
#
#   location.city location.country          location.crossStreet  \
# 0  Philadelphia    United States           btwn 11th & 12th St
# 1  Philadelphia    United States                           NaN
# 2  Philadelphia    United States                           NaN
# 3  Philadelphia    United States  btwn Chestnut St & Market St
# 4  Philadelphia    United States                           NaN
#
#    location.distance                          location.formattedAddress  \
# 0                538  [1116 Walnut St (btwn 11th & 12th St), Philade...
# 1                697  [915 Arch St, Philadelphia, PA 19107, United S...
# 2                580  [28 S 18th St, Philadelphia, PA 19103, United ...
# 3                707  [39-41 S 19th St (btwn Chestnut St & Market St...
# 4                662  [221 N 11th St, Philadelphia, PA 19107, United...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 39.94878527635662...     39.948785
# 1  [{'label': 'display', 'lat': 39.95360784404011...     39.953608
# 2  [{'label': 'display', 'lat': 39.95225354521868...     39.952254
# 3  [{'label': 'display', 'lat': 39.95223521835672...     39.952235
# 4  [{'label': 'display', 'lat': 39.95630013182966...     39.956300
#
#    location.lng location.postalCode location.state  \
# 0    -75.159855               19107             PA
# 1    -75.155434               19107             PA
# 2    -75.170296               19103             PA
# 3    -75.171792               19103             PA
# 4    -75.157318               19107             PA
#
#                                 name    referralId venuePage.id
# 0  Moriarty's Restaurant & Irish Pub  v-1581626932          NaN
# 1                   E Mei Restaurant  v-1581626932    418158388
# 2             Midtown III Restaurant  v-1581626932          NaN
# 3            Smiths Restaurant & Bar  v-1581626932     82045860
# 4                 Vietnam Restaurant  v-1581626932          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                                 name             categories          address  \
# 0  Moriarty's Restaurant & Irish Pub                    Pub   1116 Walnut St
# 1                   E Mei Restaurant     Chinese Restaurant      915 Arch St
# 2             Midtown III Restaurant                  Diner     28 S 18th St
# 3            Smiths Restaurant & Bar             Sports Bar  39-41 S 19th St
# 4                 Vietnam Restaurant  Vietnamese Restaurant    221 N 11th St
#
#    cc          city        country                   crossStreet  distance  \
# 0  US  Philadelphia  United States           btwn 11th & 12th St       538
# 1  US  Philadelphia  United States                           NaN       697
# 2  US  Philadelphia  United States                           NaN       580
# 3  US  Philadelphia  United States  btwn Chestnut St & Market St       707
# 4  US  Philadelphia  United States                           NaN       662
#
#                                     formattedAddress  \
# 0  [1116 Walnut St (btwn 11th & 12th St), Philade...
# 1  [915 Arch St, Philadelphia, PA 19107, United S...
# 2  [28 S 18th St, Philadelphia, PA 19103, United ...
# 3  [39-41 S 19th St (btwn Chestnut St & Market St...
# 4  [221 N 11th St, Philadelphia, PA 19107, United...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 39.94878527635662...  39.948785 -75.159855
# 1  [{'label': 'display', 'lat': 39.95360784404011...  39.953608 -75.155434
# 2  [{'label': 'display', 'lat': 39.95225354521868...  39.952254 -75.170296
# 3  [{'label': 'display', 'lat': 39.95223521835672...  39.952235 -75.171792
# 4  [{'label': 'display', 'lat': 39.95630013182966...  39.956300 -75.157318
#
#   postalCode state                        id
# 0      19107    PA  40b28c80f964a52033f91ee3
# 1      19107    PA  4d85387c61676dcb586b85e4
# 2      19103    PA  4a620924f964a520dfc21fe3
# 3      19103    PA  49f124b5f964a52090691fe3
# 4      19107    PA  4d3cb0f98edf3704b8c2b2a5

# %%
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                                 name  \
# 0                  Moriarty's Restaurant & Irish Pub
# 1                                   E Mei Restaurant
# 2                             Midtown III Restaurant
# 3                            Smiths Restaurant & Bar
# 4                                 Vietnam Restaurant
# 5              Lacroix Restaurant at The Rittenhouse
# 6                      Ocean City Seafood Restaurant
# 7                     Iron Hill Brewery & Restaurant
# 8                General Restaurant Equipment Supply
# 9                                       M Restaurant
# 10  Square On Square Contemporary Chinese Restaurant
# 11                                Chinese Restaurant
# 12                         Misso Japanese Restaurant
# 13                    Real Taste Teahouse Restaurant
# 14    Cuba Libre Restaurant & Rum Bar - Philadelphia
# 15                         Good Dog Bar & Restaurant
# 16                       Tampopo Japanese Restaurant
# 17                            North Third Restaurant
# 18                            Penn Center Restaurant
# 19                                 Indian Restaurant
# 20                       APJ Texas Wiener Restaurant
# 21                  The Black Sheep Pub & Restaurant
# 22                 Economy Restaurant and Bar Supply
# 23                           Sazon Restaurant & Cafe
# 24                            Knock Restaurant & Bar
# 25             Restaurant At The End Of The Universe
# 26                                 Restaurant Clicks
# 27      The Restaurant School at Walnut Hill College
# 28               Hardena Waroeng Surabaya Restaurant
# 29                              Opa Greek Restaurant
#
#                    categories                address        lat        lng  \
# 0                         Pub         1116 Walnut St  39.948785 -75.159855
# 1          Chinese Restaurant            915 Arch St  39.953608 -75.155434
# 2                       Diner           28 S 18th St  39.952254 -75.170296
# 3                  Sports Bar        39-41 S 19th St  39.952235 -75.171792
# 4       Vietnamese Restaurant          221 N 11th St  39.956300 -75.157318
# 5                  Restaurant   210 W Rittenhouse Sq  39.949683 -75.172693
# 6          Dim Sum Restaurant           234 N 9th St  39.956269 -75.154141
# 7                     Brewery         1150 Market St  39.951840 -75.159455
# 8      Furniture / Home Store         1018 Cherry St  39.954389 -75.156913
# 9         American Restaurant           231 S 8th St  39.947301 -75.154198
# 10         Chinese Restaurant       1905 Chestnut St  39.951977 -75.172173
# 11           Asian Restaurant          104 N 10th St  39.953852 -75.156217
# 12           Sushi Restaurant         1326 Spruce St  39.946840 -75.163895
# 13         Chinese Restaurant            925 Race St  39.953555 -75.154622
# 14           Cuban Restaurant            10 S 2nd St  39.949548 -75.143881
# 15                        Bar          224 S 15th St  39.948765 -75.166123
# 16           Asian Restaurant          719 Sansom St  39.948839 -75.154512
# 17        American Restaurant           801 N 3rd St  39.963445 -75.142862
# 18        American Restaurant                    NaN  39.953568 -75.166529
# 19    North Indian Restaurant      1634 South Street  39.944030 -75.169950
# 20        American Restaurant           47 N 13th St  39.953631 -75.160939
# 21                        Pub          247 S 17th St  39.948414 -75.169432
# 22            Warehouse Store         69-71 N 2nd St  39.951762 -75.143129
# 23  South American Restaurant   941 Spring Garden St  39.961705 -75.154435
# 24        American Restaurant          225 S 12th St  39.947846 -75.160744
# 25              Moving Target                    NaN  39.956647 -75.165990
# 26         Advertising Agency  211 N 13th St Ste 800  39.956434 -75.160301
# 27               Trade School         4207 Walnut St  39.955125 -75.207472
# 28      Indonesian Restaurant        1754 S Hicks St  39.928379 -75.171205
# 29           Greek Restaurant                    NaN  39.949928 -75.162350
#
#    postalCode state
# 0       19107    PA
# 1       19107    PA
# 2       19103    PA
# 3       19103    PA
# 4       19107    PA
# 5       19103    PA
# 6       19107    PA
# 7       19107    PA
# 8       19107    PA
# 9       19106    PA
# 10      19103    PA
# 11      19107    PA
# 12      19107    PA
# 13      19107    PA
# 14      19106    PA
# 15      19102    PA
# 16      19106    PA
# 17      19123    PA
# 18      19103    PA
# 19      19146    PA
# 20      19107    PA
# 21      19103    PA
# 22      19106    PA
# 23      19123    PA
# 24      19107    PA
# 25      19102    PA
# 26      19107    PA
# 27      19104    PA
# 28      19145    PA
# 29        NaN    PA

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                                 name  \
# 0                  Moriarty's Restaurant & Irish Pub
# 1                                   E Mei Restaurant
# 2                             Midtown III Restaurant
# 3                            Smiths Restaurant & Bar
# 4                                 Vietnam Restaurant
# 5              Lacroix Restaurant at The Rittenhouse
# 6                      Ocean City Seafood Restaurant
# 7                     Iron Hill Brewery & Restaurant
# 8                General Restaurant Equipment Supply
# 9                                       M Restaurant
# 10  Square On Square Contemporary Chinese Restaurant
# 11                                Chinese Restaurant
# 12                         Misso Japanese Restaurant
# 13                    Real Taste Teahouse Restaurant
# 14    Cuba Libre Restaurant & Rum Bar - Philadelphia
# 15                         Good Dog Bar & Restaurant
# 16                       Tampopo Japanese Restaurant
# 17                            North Third Restaurant
# 19                                 Indian Restaurant
# 20                       APJ Texas Wiener Restaurant
# 21                  The Black Sheep Pub & Restaurant
# 22                 Economy Restaurant and Bar Supply
# 23                           Sazon Restaurant & Cafe
# 24                            Knock Restaurant & Bar
# 26                                 Restaurant Clicks
# 27      The Restaurant School at Walnut Hill College
# 28               Hardena Waroeng Surabaya Restaurant
#
#                    categories                address        lat        lng  \
# 0                         Pub         1116 Walnut St  39.948785 -75.159855
# 1          Chinese Restaurant            915 Arch St  39.953608 -75.155434
# 2                       Diner           28 S 18th St  39.952254 -75.170296
# 3                  Sports Bar        39-41 S 19th St  39.952235 -75.171792
# 4       Vietnamese Restaurant          221 N 11th St  39.956300 -75.157318
# 5                  Restaurant   210 W Rittenhouse Sq  39.949683 -75.172693
# 6          Dim Sum Restaurant           234 N 9th St  39.956269 -75.154141
# 7                     Brewery         1150 Market St  39.951840 -75.159455
# 8      Furniture / Home Store         1018 Cherry St  39.954389 -75.156913
# 9         American Restaurant           231 S 8th St  39.947301 -75.154198
# 10         Chinese Restaurant       1905 Chestnut St  39.951977 -75.172173
# 11           Asian Restaurant          104 N 10th St  39.953852 -75.156217
# 12           Sushi Restaurant         1326 Spruce St  39.946840 -75.163895
# 13         Chinese Restaurant            925 Race St  39.953555 -75.154622
# 14           Cuban Restaurant            10 S 2nd St  39.949548 -75.143881
# 15                        Bar          224 S 15th St  39.948765 -75.166123
# 16           Asian Restaurant          719 Sansom St  39.948839 -75.154512
# 17        American Restaurant           801 N 3rd St  39.963445 -75.142862
# 19    North Indian Restaurant      1634 South Street  39.944030 -75.169950
# 20        American Restaurant           47 N 13th St  39.953631 -75.160939
# 21                        Pub          247 S 17th St  39.948414 -75.169432
# 22            Warehouse Store         69-71 N 2nd St  39.951762 -75.143129
# 23  South American Restaurant   941 Spring Garden St  39.961705 -75.154435
# 24        American Restaurant          225 S 12th St  39.947846 -75.160744
# 26         Advertising Agency  211 N 13th St Ste 800  39.956434 -75.160301
# 27               Trade School         4207 Walnut St  39.955125 -75.207472
# 28      Indonesian Restaurant        1754 S Hicks St  39.928379 -75.171205
#
#    postalCode state
# 0       19107    PA
# 1       19107    PA
# 2       19103    PA
# 3       19103    PA
# 4       19107    PA
# 5       19103    PA
# 6       19107    PA
# 7       19107    PA
# 8       19107    PA
# 9       19106    PA
# 10      19103    PA
# 11      19107    PA
# 12      19107    PA
# 13      19107    PA
# 14      19106    PA
# 15      19102    PA
# 16      19106    PA
# 17      19123    PA
# 19      19146    PA
# 20      19107    PA
# 21      19103    PA
# 22      19106    PA
# 23      19123    PA
# 24      19107    PA
# 26      19107    PA
# 27      19104    PA
# 28      19145    PA

# %% [markdown]
# # Search for Cafeteria

# %%
# search for Cafeteria
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=GEOB3Q4RTF3RYS1WW0YUO1K1TH2S3JACF40KFZGGILESXARV&client_secret=DZT1HG4VZQFFQVQRZLIVQ25HFWJAEAWIEKKO2AYGE1HHOB3J&ll=39.9527237,-75.1635262&v=20200212&query=Cafeteria&radius=10000'

# %%
# Send the GET Request and examine the results
cresults = requests.get(url).json()
#cresults

# %%
# assign relevant part of JSON to venues
venues = cresults['response']['venues']

# tranform venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1a1941735', 'name': 'C...    False
# 1  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 2  [{'id': '54f4ba06498e2cf5561da814', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d1a1941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d1a1941735', 'name': 'C...    False
#
#                          id            location.address location.cc  \
# 0  4c98ca9b4804a143d584ee0e            Bonnell Building          US
# 1  50fc34d8e4b0937c7ee94987  Philadelphia Museum of Art          US
# 2  5bd1ef8c46e1b6002cc08649                1800 Arch St          US
# 3  512cfb27e4b0c7118ac65b0a              1025 Walnut St          US
# 4  4d34858f6c7c721e39d8c256  Cooper University Hospital          US
#
#   location.city location.country               location.crossStreet  \
# 0  Philadelphia    United States  Community College of Philadelphia
# 1  Philadelphia    United States                          1st Floor
# 2  Philadelphia    United States                                NaN
# 3  Philadelphia    United States                                NaN
# 4        Camden    United States                                NaN
#
#    location.distance                          location.formattedAddress  \
# 0               1048  [Bonnell Building (Community College of Philad...
# 1               2062  [Philadelphia Museum of Art (1st Floor), Phila...
# 2                610  [1800 Arch St, Philadelphia, PA 19103, United ...
# 3                610  [1025 Walnut St, Philadelphia, PA 19107, Unite...
# 4               4226  [Cooper University Hospital, Camden, NJ 08103,...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 39.96197657816427...     39.961977
# 1  [{'label': 'display', 'lat': 39.96509849221878...     39.965098
# 2  [{'label': 'display', 'lat': 39.95494946560051...     39.954949
# 3  [{'label': 'display', 'lat': 39.949461, 'lng':...     39.949461
# 4  [{'label': 'display', 'lat': 39.94161270909661...     39.941613
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -75.165810                   NaN               19130             PA
# 1    -75.181517                   NaN               19130             PA
# 2    -75.170067          Logan Square               19103             PA
# 3    -75.157773                   NaN               19107             PA
# 4    -75.116173                   NaN               08103             NJ
#
#                               name    referralId venuePage.id
# 0                        Cafeteria  v-1581627139          NaN
# 1             Art Museum Cafeteria  v-1581627139          NaN
# 2                    CTC Cafeteria  v-1581627139          NaN
# 3  Jefferson Alumni Hall Cafeteria  v-1581627139          NaN
# 4                        Cafeteria  v-1581627139          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                               name           categories  \
# 0                        Cafeteria    College Cafeteria
# 1             Art Museum Cafeteria                 Café
# 2                    CTC Cafeteria  Corporate Cafeteria
# 3  Jefferson Alumni Hall Cafeteria    College Cafeteria
# 4                        Cafeteria    College Cafeteria
#
#                       address  cc          city        country  \
# 0            Bonnell Building  US  Philadelphia  United States
# 1  Philadelphia Museum of Art  US  Philadelphia  United States
# 2                1800 Arch St  US  Philadelphia  United States
# 3              1025 Walnut St  US  Philadelphia  United States
# 4  Cooper University Hospital  US        Camden  United States
#
#                          crossStreet  distance  \
# 0  Community College of Philadelphia      1048
# 1                          1st Floor      2062
# 2                                NaN       610
# 3                                NaN       610
# 4                                NaN      4226
#
#                                     formattedAddress  \
# 0  [Bonnell Building (Community College of Philad...
# 1  [Philadelphia Museum of Art (1st Floor), Phila...
# 2  [1800 Arch St, Philadelphia, PA 19103, United ...
# 3  [1025 Walnut St, Philadelphia, PA 19107, Unite...
# 4  [Cooper University Hospital, Camden, NJ 08103,...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 39.96197657816427...  39.961977 -75.165810
# 1  [{'label': 'display', 'lat': 39.96509849221878...  39.965098 -75.181517
# 2  [{'label': 'display', 'lat': 39.95494946560051...  39.954949 -75.170067
# 3  [{'label': 'display', 'lat': 39.949461, 'lng':...  39.949461 -75.157773
# 4  [{'label': 'display', 'lat': 39.94161270909661...  39.941613 -75.116173
#
#    neighborhood postalCode state                        id
# 0           NaN      19130    PA  4c98ca9b4804a143d584ee0e
# 1           NaN      19130    PA  50fc34d8e4b0937c7ee94987
# 2  Logan Square      19103    PA  5bd1ef8c46e1b6002cc08649
# 3           NaN      19107    PA  512cfb27e4b0c7118ac65b0a
# 4           NaN      08103    NJ  4d34858f6c7c721e39d8c256

# %%
# delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                           name                    categories  \
# 0                                    Cafeteria             College Cafeteria
# 1                         Art Museum Cafeteria                          Café
# 2                                CTC Cafeteria           Corporate Cafeteria
# 3              Jefferson Alumni Hall Cafeteria             College Cafeteria
# 4                                    Cafeteria             College Cafeteria
# 5                     Claims College Cafeteria             College Cafeteria
# 6                       Duane Morris Cafeteria                     Cafeteria
# 7              Basement H&M Employee Cafeteria                Clothing Store
# 8               Hahnemann University Cafeteria  General College & University
# 9                       Sodexo Cafeteria @ GSK           American Restaurant
# 10     Hahnemann University Hospital Cafeteria                     Cafeteria
# 11         Jefferson Hospital Atrium Cafeteria                     Cafeteria
# 12                               IBC Cafeteria                     Cafeteria
# 13   Moore College Of Art And Design Cafeteria             College Cafeteria
# 14  Reliance Standard Life Insurance Cafeteria                     Cafeteria
# 15             Pennsylvania Hospital Cafeteria                          Café
# 16                    Loews Philadelphia Hotel                         Hotel
# 17                    PEIRCE COLLEGE Cafeteria             College Cafeteria
# 18                               FRB Cafeteria                          Café
# 19                              Capa Cafeteria                    Food Court
# 20                         Masterman Cafeteria                    Restaurant
# 21                              PPMC Cafeteria                     Cafeteria
# 22                             ACP's Cafeteria                          Café
# 23                     The Enchanted Cafeteria                   Beer Garden
# 24   Shriner's Hospital for Children Cafeteria                     Cafeteria
# 25                                   Cafeteria                      Building
# 26                      AFSCME DC 33 Cafeteria                    Restaurant
# 27                               HUP Cafeteria                     Cafeteria
# 28                                   Cafeteria                 Middle School
# 29                            AFSCME Cafeteria           American Restaurant
#
#                        address        lat        lng  neighborhood postalCode  \
# 0             Bonnell Building  39.961977 -75.165810           NaN      19130
# 1   Philadelphia Museum of Art  39.965098 -75.181517           NaN      19130
# 2                 1800 Arch St  39.954949 -75.170067  Logan Square      19103
# 3               1025 Walnut St  39.949461 -75.157773           NaN      19107
# 4   Cooper University Hospital  39.941613 -75.116173           NaN      08103
# 5                          NaN  39.952316 -75.160635           NaN        NaN
# 6                  18th Street  39.952084 -75.168854           NaN      19103
# 7                          NaN  39.951385 -75.167020           NaN      19102
# 8                          NaN  39.957546 -75.162630           NaN        NaN
# 9                200 N 16th St  39.957088 -75.166235           NaN      19102
# 10                         NaN  39.957368 -75.162932           NaN        NaN
# 11             110 S. 10th St.  39.949971 -75.158166           NaN      19107
# 12              1901 Market St  39.953444 -75.171805           NaN      19103
# 13                         NaN  39.956862 -75.172291           NaN      19103
# 14                         NaN  39.954265 -75.173465           NaN      19103
# 15               800 Spruce St  39.945200 -75.155295           NaN      19107
# 16              1200 Market St  39.951419 -75.160303           NaN      19107
# 17                1420 Pine St  39.945668 -75.166225           NaN      19102
# 18                         NaN  39.953642 -75.150419           NaN      19106
# 19                         NaN  39.942109 -75.164148           NaN        NaN
# 20       1699 Spring Garden St  39.963437 -75.165718           NaN      19130
# 21                         NaN  39.958739 -75.197647           NaN      19104
# 22                         NaN  39.957771 -75.150673           NaN      19106
# 23                         NaN  39.941090 -75.159054           NaN        NaN
# 24                  S Broad St  40.007185 -75.151394           NaN      19109
# 25                         NaN  39.923003 -75.103337           NaN        NaN
# 26              3001 Walnut St  39.952080 -75.184391           NaN      19104
# 27              3400 Spruce St  39.949885 -75.194056           NaN      19104
# 28                         NaN  39.985424 -75.236435           NaN      19131
# 29              3001 Walnut St  39.952665 -75.184653           NaN      19104
#
#            state
# 0             PA
# 1             PA
# 2             PA
# 3             PA
# 4             NJ
# 5             PA
# 6             PA
# 7             PA
# 8   Pennsylvania
# 9             PA
# 10            PA
# 11            PA
# 12            PA
# 13            PA
# 14            PA
# 15            PA
# 16            PA
# 17            PA
# 18            PA
# 19            PA
# 20            PA
# 21            PA
# 22            PA
# 23            PA
# 24            PA
# 25            NJ
# 26            PA
# 27            PA
# 28            PA
# 29            PA

# %%
# delete rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#             name           categories       address        lat        lng  \
# 2  CTC Cafeteria  Corporate Cafeteria  1800 Arch St  39.954949 -75.170067
#
#    neighborhood postalCode state
# 2  Logan Square      19103    PA

# %% [markdown]
# # Search for Shopping stories

# %%
# search for Shopping
search_query = 'Shopping'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=GEOB3Q4RTF3RYS1WW0YUO1K1TH2S3JACF40KFZGGILESXARV&client_secret=DZT1HG4VZQFFQVQRZLIVQ25HFWJAEAWIEKKO2AYGE1HHOB3J&ll=39.9527237,-75.1635262&v=20200212&query=Shopping&radius=1000'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d107951735', 'name': 'S...    False
# 1  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
#
#                          id     location.address location.cc location.city  \
# 0  55bef1b8498ec078805c74b1       1509 Walnut St          US  Philadelphia
# 1  4fc8fa70e4b0ccf717c72c64                  NaN          US  Philadelphia
# 2  55af9310498e5120ee5f91cf  1217 Sansom St Fl 8          US  Philadelphia
#
#   location.country  location.distance  \
# 0    United States                401
# 1    United States                447
# 2    United States                377
#
#                            location.formattedAddress  \
# 0  [1509 Walnut St, Philadelphia, PA 19102, Unite...
# 1            [Philadelphia, PA 19103, United States]
# 2  [1217 Sansom St Fl 8, Philadelphia, PA 19107, ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 39.949843, 'lng':...     39.949843
# 1  [{'label': 'display', 'lat': 39.94973955025363...     39.949740
# 2  [{'label': 'display', 'lat': 39.94984799293115...     39.949848
#
#    location.lng location.postalCode location.state                    name  \
# 0    -75.166356               19102             PA  On-Line Shopping Store
# 1    -75.167047               19103             PA  Walnut Street Shopping
# 2    -75.161183               19107             PA     PayrollShopping.com
#
#      referralId
# 0  v-1581627235
# 1  v-1581627235
# 2  v-1581627235

# %%
# keep only columns that include venue name, and anything that is associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                      name     categories              address  cc  \
# 0  On-Line Shopping Store     Shoe Store       1509 Walnut St  US
# 1  Walnut Street Shopping  Shopping Mall                  NaN  US
# 2     PayrollShopping.com         Office  1217 Sansom St Fl 8  US
#
#            city        country  distance  \
# 0  Philadelphia  United States       401
# 1  Philadelphia  United States       447
# 2  Philadelphia  United States       377
#
#                                     formattedAddress  \
# 0  [1509 Walnut St, Philadelphia, PA 19102, Unite...
# 1            [Philadelphia, PA 19103, United States]
# 2  [1217 Sansom St Fl 8, Philadelphia, PA 19107, ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 39.949843, 'lng':...  39.949843 -75.166356
# 1  [{'label': 'display', 'lat': 39.94973955025363...  39.949740 -75.167047
# 2  [{'label': 'display', 'lat': 39.94984799293115...  39.949848 -75.161183
#
#   postalCode state                        id
# 0      19102    PA  55bef1b8498ec078805c74b1
# 1      19103    PA  4fc8fa70e4b0ccf717c72c64
# 2      19107    PA  55af9310498e5120ee5f91cf

# %%
# delete unnecessary columns
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                      name     categories              address        lat  \
# 0  On-Line Shopping Store     Shoe Store       1509 Walnut St  39.949843
# 1  Walnut Street Shopping  Shopping Mall                  NaN  39.949740
# 2     PayrollShopping.com         Office  1217 Sansom St Fl 8  39.949848
#
#          lng postalCode state
# 0 -75.166356      19102    PA
# 1 -75.167047      19103    PA
# 2 -75.161183      19107    PA

# %%
# delete rows which its category is not Shopping Mall
df_Shopping = clean_Shopping_dataframe2[clean_Shopping_dataframe2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                      name     categories address       lat        lng  \
# 1  Walnut Street Shopping  Shopping Mall     NaN  39.94974 -75.167047
#
#   postalCode state
# 1      19103    PA

# %% [markdown]
# # Search for Parks

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}'\
.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=GEOB3Q4RTF3RYS1WW0YUO1K1TH2S3JACF40KFZGGILESXARV&client_secret=DZT1HG4VZQFFQVQRZLIVQ25HFWJAEAWIEKKO2AYGE1HHOB3J&ll=39.9527237,-75.1635262&v=20200212&query=Park&radius=10000'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()
#presults

# %%
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d164941735', 'name': 'P...         NaN
# 1  [{'id': '52e81612bcbc57f1066b7a21', 'name': 'N...         NaN
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...         NaN
# 3  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...         NaN
# 4  [{'id': '4c38df4de52ce0d596b336e1', 'name': 'P...         NaN
#
#   delivery.provider.icon.name delivery.provider.icon.prefix  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.name delivery.url  hasPerk  \
# 0                          NaN                    NaN          NaN    False
# 1                          NaN                    NaN          NaN    False
# 2                          NaN                    NaN          NaN    False
# 3                          NaN                    NaN          NaN    False
# 4                          NaN                    NaN          NaN    False
#
#                          id          location.address location.cc  \
# 0  4aa14edef964a5206d4020e3  1501 John F Kennedy Blvd          US
# 1  4b6c740af964a520683b2ce3              143 S 3rd St          US
# 2  4bde0d566198c9b6c5cc12ff                 1 Penn Sq          US
# 3  4c12402077cea5936aa7cc60              Logan Circle          US
# 4  520d435011d2d981c69d2125             123 S 12th St          US
#
#   location.city location.country    location.crossStreet  location.distance  \
# 0  Philadelphia    United States            at N 15th St                217
# 1  Philadelphia    United States   btwn Race & Walnut St               1194
# 2  Philadelphia    United States  West Side of City Hall                102
# 3  Philadelphia    United States    at Ben Franklin Pkwy                757
# 4  Philadelphia    United States            at Sansom St                326
#
#                            location.formattedAddress  \
# 0  [1501 John F Kennedy Blvd (at N 15th St), Phil...
# 1  [143 S 3rd St (btwn Race & Walnut St), Philade...
# 2  [1 Penn Sq (West Side of City Hall), Philadelp...
# 3  [Logan Circle (at Ben Franklin Pkwy), Philadel...
# 4  [123 S 12th St (at Sansom St), Philadelphia, P...
#
#                              location.labeledLatLngs  location.lat  \
# 0                                                NaN     39.954123
# 1  [{'label': 'display', 'lat': 39.95066565989744...     39.950666
# 2  [{'label': 'display', 'lat': 39.95277184634310...     39.952772
# 3  [{'label': 'display', 'lat': 39.95785953028045...     39.957860
# 4  [{'label': 'display', 'lat': 39.95043650206751...     39.950437
#
#    location.lng     location.neighborhood location.postalCode location.state  \
# 0    -75.165303                       NaN               19102             PA
# 1    -75.149787                       NaN               19106             PA
# 2    -75.164723  Avenue of the Arts South               19102             PA
# 3    -75.169344                       NaN               19103             PA
# 4    -75.161136          Center City East               19107             PA
#
#                                     name    referralId
# 0                  JFK Plaza / Love Park  v-1581627396
# 1  Independence National Historical Park  v-1581627396
# 2                          Dilworth Park  v-1581627396
# 3                     Sister Cities Park  v-1581627396
# 4                     Park America, Inc.  v-1581627396

# %%
# keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                                     name     categories  \
# 0                  JFK Plaza / Love Park          Plaza
# 1  Independence National Historical Park  National Park
# 2                          Dilworth Park           Park
# 3                     Sister Cities Park           Park
# 4                     Park America, Inc.        Parking
#
#                     address  cc          city        country  \
# 0  1501 John F Kennedy Blvd  US  Philadelphia  United States
# 1              143 S 3rd St  US  Philadelphia  United States
# 2                 1 Penn Sq  US  Philadelphia  United States
# 3              Logan Circle  US  Philadelphia  United States
# 4             123 S 12th St  US  Philadelphia  United States
#
#               crossStreet  distance  \
# 0            at N 15th St       217
# 1   btwn Race & Walnut St      1194
# 2  West Side of City Hall       102
# 3    at Ben Franklin Pkwy       757
# 4            at Sansom St       326
#
#                                     formattedAddress  \
# 0  [1501 John F Kennedy Blvd (at N 15th St), Phil...
# 1  [143 S 3rd St (btwn Race & Walnut St), Philade...
# 2  [1 Penn Sq (West Side of City Hall), Philadelp...
# 3  [Logan Circle (at Ben Franklin Pkwy), Philadel...
# 4  [123 S 12th St (at Sansom St), Philadelphia, P...
#
#                                       labeledLatLngs        lat        lng  \
# 0                                                NaN  39.954123 -75.165303
# 1  [{'label': 'display', 'lat': 39.95066565989744...  39.950666 -75.149787
# 2  [{'label': 'display', 'lat': 39.95277184634310...  39.952772 -75.164723
# 3  [{'label': 'display', 'lat': 39.95785953028045...  39.957860 -75.169344
# 4  [{'label': 'display', 'lat': 39.95043650206751...  39.950437 -75.161136
#
#                neighborhood postalCode state                        id
# 0                       NaN      19102    PA  4aa14edef964a5206d4020e3
# 1                       NaN      19106    PA  4b6c740af964a520683b2ce3
# 2  Avenue of the Arts South      19102    PA  4bde0d566198c9b6c5cc12ff
# 3                       NaN      19103    PA  4c12402077cea5936aa7cc60
# 4          Center City East      19107    PA  520d435011d2d981c69d2125

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                               name          categories  \
# 0                            JFK Plaza / Love Park               Plaza
# 1            Independence National Historical Park       National Park
# 2                                    Dilworth Park                Park
# 3                               Sister Cities Park                Park
# 4                               Park America, Inc.             Parking
# 5                                   Fairmount Park                Park
# 6                             Ned Smyth World Park                Park
# 7                      Louis I. Kahn Memorial Park                Park
# 8                                 Towne Park Valet             Parking
# 9                            Matthias Baldwin Park                Park
# 10                                      Seger Park                Park
# 11                 Franklin Square Park Playground          Playground
# 12                       Schuylkill River Dog Park             Dog Run
# 13                            Park Towne Place Gym                 Gym
# 14                              Dilworth Park Cafe         Coffee Shop
# 15     Rothman Institute Ice Rink at Dilworth Park        Skating Rink
# 16                           Schuylkill River Park                Park
# 17                              Liberty Lands Park                Park
# 18                                    Aviator Park                Park
# 19                           Franklin Science Park          Playground
# 20  Roberto Clemente Playground, Park & Rec Center          Playground
# 21                   Wintergarden at Dilworth Park              Garden
# 22                                   Park & Polish            Car Wash
# 23                                      Paine Park          Skate Park
# 24                         Penn's Landing Dog Park             Dog Run
# 25                          Park Towne Supermarket  Miscellaneous Shop
# 26      Albert M. Greenfield Lawn at Dilworth Park                Park
# 27                           Orianna Hill Dog Park             Dog Run
# 28                           Dickinson Square Park                Park
# 29                            Park Side Beef & Ale                 Pub
#
#                                address        lat        lng  \
# 0             1501 John F Kennedy Blvd  39.954123 -75.165303
# 1                         143 S 3rd St  39.950666 -75.149787
# 2                            1 Penn Sq  39.952772 -75.164723
# 3                         Logan Circle  39.957860 -75.169344
# 4                        123 S 12th St  39.950437 -75.161136
# 5                       N Concourse St  39.982903 -75.211187
# 6                              N 12 St  39.952924 -75.160157
# 7                  11th St. & Pine St.  39.945092 -75.159960
# 8                       1200 Market St  39.951166 -75.159994
# 9   Franklin Town Blvd & Callowhill St  39.961497 -75.169026
# 10                     1020 Lombard St  39.943603 -75.159254
# 11                             Race St  39.955807 -75.151184
# 12               25th St and Spruce St  39.949212 -75.182288
# 13         2200 Benjamin Franklin Pkwy  39.960354 -75.177494
# 14            1400 John F Kennedy Blvd  39.953026 -75.164460
# 15                           1 Penn Sq  39.952770 -75.164561
# 16                     2568 Walnut St.  39.949160 -75.182060
# 17                            N 3rd St  39.965609 -75.142045
# 18                       223 N 20th St  39.958078 -75.172263
# 19                       2001 Race St.  39.958065 -75.172747
# 20                   1800 Mt Vernon St  39.965359 -75.168067
# 21                         1 S 15th St  39.952713 -75.164980
# 22                                 NaN  39.953000 -75.162760
# 23          3001 Martin Luther King Dr  39.962827 -75.180407
# 24                            Front St  39.949625 -75.139599
# 25         2200 Benjamin Franklin Pkwy  39.960533 -75.177386
# 26                           1 Penn Sq  39.952180 -75.164675
# 27                   903 N Orianna St.  39.965621 -75.142861
# 28              1600 E Moyamensing Ave  39.927839 -75.151497
# 29                        1433 Arch St  39.954827 -75.164595
#
#                 neighborhood postalCode state
# 0                        NaN      19102    PA
# 1                        NaN      19106    PA
# 2   Avenue of the Arts South      19102    PA
# 3                        NaN      19103    PA
# 4           Center City East      19107    PA
# 5                        NaN      19131    PA
# 6           Center City East      19107    PA
# 7                        NaN      19107    PA
# 8                        NaN      19107    PA
# 9                        NaN      19130    PA
# 10                       NaN      19147    PA
# 11                       NaN      19123    PA
# 12                       NaN      19103    PA
# 13                       NaN      19130    PA
# 14                       NaN      19107    PA
# 15  Avenue of the Arts South      19102    PA
# 16                       NaN      19103    PA
# 17        Northern Liberties      19123    PA
# 18                       NaN      19103    PA
# 19                       NaN      19103    PA
# 20                       NaN      19130    PA
# 21                       NaN      19102    PA
# 22                       NaN      19107    PA
# 23                       NaN      19104    PA
# 24                       NaN      19106    PA
# 25                       NaN      19130    PA
# 26                       NaN      19102    PA
# 27                       NaN      19123    PA
# 28                       NaN      19148    PA
# 29                       NaN      19102    PA

# %%
# delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                            name    categories        address  \
# 2                                 Dilworth Park          Park      1 Penn Sq
# 4                            Park America, Inc.       Parking  123 S 12th St
# 6                          Ned Smyth World Park          Park        N 12 St
# 15  Rothman Institute Ice Rink at Dilworth Park  Skating Rink      1 Penn Sq
# 17                           Liberty Lands Park          Park       N 3rd St
#
#           lat        lng              neighborhood postalCode state
# 2   39.952772 -75.164723  Avenue of the Arts South      19102    PA
# 4   39.950437 -75.161136          Center City East      19107    PA
# 6   39.952924 -75.160157          Center City East      19107    PA
# 15  39.952770 -75.164561  Avenue of the Arts South      19102    PA
# 17  39.965609 -75.142045        Northern Liberties      19123    PA

# %%
# delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                     name categories    address        lat        lng  \
# 2          Dilworth Park       Park  1 Penn Sq  39.952772 -75.164723
# 6   Ned Smyth World Park       Park    N 12 St  39.952924 -75.160157
# 17    Liberty Lands Park       Park   N 3rd St  39.965609 -75.142045
#
#                 neighborhood postalCode state
# 2   Avenue of the Arts South      19102    PA
# 6           Center City East      19107    PA
# 17        Northern Liberties      19123    PA

# %% [markdown]
# # Generate map to visualize hotels, shopping stores and Cafeteria and how they cluster together

# %%
# create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([clean_grocerystore_dataframe3, df_hotel, df_Cafeteria, df_Shopping], ignore_index=True)
hotel_neighbourhood_df
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   app.launch_new_instance()
#                         address                 categories        lat  \
# 0                1227 S 18th St              Grocery Store  39.935849
# 1   2200 Benjamin Franklin Pkwy              Grocery Store  39.958787
# 2               1500 S Broad St          Food & Drink Shop  39.931673
# 3                    7th Street              Grocery Store  39.922412
# 4              115 W Girard Ave  Middle Eastern Restaurant  39.969112
# 5               1000 Snyder Ave              Grocery Store  39.923217
# 6               South Camac St.              Grocery Store  39.916994
# 7                   17th Street         Mexican Restaurant  39.964811
# 8                2200 S 20th St              Deli / Bodega  39.924285
# 9             400 McKean Street              Deli / Bodega  39.923715
# 10            1770 N Mascher St              Deli / Bodega  39.977352
# 11                  625 Avon St              Deli / Bodega  39.937223
# 12         3000 W Cumberland St              Deli / Bodega  39.994268
# 13         3319 W Cumberland St                Pizza Place  39.995022
# 14                 1800 Arch St        Corporate Cafeteria  39.954949
# 15                          NaN              Shopping Mall  39.949740
#
#           lng                               name  neighborhood postalCode  \
# 0  -75.173754            Fernandez Grocery Store           NaN      19146
# 1  -75.175407                      Grocery Store           NaN      19130
# 2  -75.168482                   88 Grocery Store           NaN      19146
# 3  -75.158218  Eak Meng: Cambodian Grocery Store           NaN      19148
# 4  -75.136764            Jerusalem Grocery Store           NaN      19123
# 5  -75.162336        10th & Snyder Grocery Store           NaN      19148
# 6  -75.168181             Venuti's Grocery Store           NaN      19148
# 7  -75.165907                     Grocery Stores           NaN      19130
# 8  -75.179552                 Anna Grocery Store           NaN      19145
# 9  -75.153132               Andrew Grocery Store           NaN      19146
# 10 -75.136037               Tamyra Grocery Store           NaN      19122
# 11 -75.122921            Freddie's Grocery Store           NaN      08103
# 12 -75.181085            Alejandro Grocery Store           NaN      19132
# 13 -75.186327       Deca Pizza and Grocery Store           NaN      19132
# 14 -75.170067                      CTC Cafeteria  Logan Square      19103
# 15 -75.167047             Walnut Street Shopping           NaN      19103
#
#    state
# 0     PA
# 1     PA
# 2     PA
# 3     PA
# 4     PA
# 5     PA
# 6     PA
# 7     PA
# 8     PA
# 9     PA
# 10    PA
# 11    NJ
# 12    PA
# 13    PA
# 14    PA
# 15    PA

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Generate map to visualize Park, Restaurant and Cafeteria and how they cluster together

# %%
# create dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   from ipykernel import kernelapp as app
#                   address                 categories        lat        lng  \
# 0               1 Penn Sq                       Park  39.952772 -75.164723
# 1                 N 12 St                       Park  39.952924 -75.160157
# 2                N 3rd St                       Park  39.965609 -75.142045
# 3          1116 Walnut St                        Pub  39.948785 -75.159855
# 4             915 Arch St         Chinese Restaurant  39.953608 -75.155434
# 5            28 S 18th St                      Diner  39.952254 -75.170296
# 6         39-41 S 19th St                 Sports Bar  39.952235 -75.171792
# 7           221 N 11th St      Vietnamese Restaurant  39.956300 -75.157318
# 8    210 W Rittenhouse Sq                 Restaurant  39.949683 -75.172693
# 9            234 N 9th St         Dim Sum Restaurant  39.956269 -75.154141
# 10         1150 Market St                    Brewery  39.951840 -75.159455
# 11         1018 Cherry St     Furniture / Home Store  39.954389 -75.156913
# 12           231 S 8th St        American Restaurant  39.947301 -75.154198
# 13       1905 Chestnut St         Chinese Restaurant  39.951977 -75.172173
# 14          104 N 10th St           Asian Restaurant  39.953852 -75.156217
# 15         1326 Spruce St           Sushi Restaurant  39.946840 -75.163895
# 16            925 Race St         Chinese Restaurant  39.953555 -75.154622
# 17            10 S 2nd St           Cuban Restaurant  39.949548 -75.143881
# 18          224 S 15th St                        Bar  39.948765 -75.166123
# 19          719 Sansom St           Asian Restaurant  39.948839 -75.154512
# 20           801 N 3rd St        American Restaurant  39.963445 -75.142862
# 21      1634 South Street    North Indian Restaurant  39.944030 -75.169950
# 22           47 N 13th St        American Restaurant  39.953631 -75.160939
# 23          247 S 17th St                        Pub  39.948414 -75.169432
# 24         69-71 N 2nd St            Warehouse Store  39.951762 -75.143129
# 25   941 Spring Garden St  South American Restaurant  39.961705 -75.154435
# 26          225 S 12th St        American Restaurant  39.947846 -75.160744
# 27  211 N 13th St Ste 800         Advertising Agency  39.956434 -75.160301
# 28         4207 Walnut St               Trade School  39.955125 -75.207472
# 29        1754 S Hicks St      Indonesian Restaurant  39.928379 -75.171205
# 30           1800 Arch St        Corporate Cafeteria  39.954949 -75.170067
#
#                                                 name  \
# 0                                      Dilworth Park
# 1                               Ned Smyth World Park
# 2                                 Liberty Lands Park
# 3                  Moriarty's Restaurant & Irish Pub
# 4                                   E Mei Restaurant
# 5                             Midtown III Restaurant
# 6                            Smiths Restaurant & Bar
# 7                                 Vietnam Restaurant
# 8              Lacroix Restaurant at The Rittenhouse
# 9                      Ocean City Seafood Restaurant
# 10                    Iron Hill Brewery & Restaurant
# 11               General Restaurant Equipment Supply
# 12                                      M Restaurant
# 13  Square On Square Contemporary Chinese Restaurant
# 14                                Chinese Restaurant
# 15                         Misso Japanese Restaurant
# 16                    Real Taste Teahouse Restaurant
# 17    Cuba Libre Restaurant & Rum Bar - Philadelphia
# 18                         Good Dog Bar & Restaurant
# 19                       Tampopo Japanese Restaurant
# 20                            North Third Restaurant
# 21                                 Indian Restaurant
# 22                       APJ Texas Wiener Restaurant
# 23                  The Black Sheep Pub & Restaurant
# 24                 Economy Restaurant and Bar Supply
# 25                           Sazon Restaurant & Cafe
# 26                            Knock Restaurant & Bar
# 27                                 Restaurant Clicks
# 28      The Restaurant School at Walnut Hill College
# 29               Hardena Waroeng Surabaya Restaurant
# 30                                     CTC Cafeteria
#
#                 neighborhood postalCode state
# 0   Avenue of the Arts South      19102    PA
# 1           Center City East      19107    PA
# 2         Northern Liberties      19123    PA
# 3                        NaN      19107    PA
# 4                        NaN      19107    PA
# 5                        NaN      19103    PA
# 6                        NaN      19103    PA
# 7                        NaN      19107    PA
# 8                        NaN      19103    PA
# 9                        NaN      19107    PA
# 10                       NaN      19107    PA
# 11                       NaN      19107    PA
# 12                       NaN      19106    PA
# 13                       NaN      19103    PA
# 14                       NaN      19107    PA
# 15                       NaN      19107    PA
# 16                       NaN      19107    PA
# 17                       NaN      19106    PA
# 18                       NaN      19102    PA
# 19                       NaN      19106    PA
# 20                       NaN      19123    PA
# 21                       NaN      19146    PA
# 22                       NaN      19107    PA
# 23                       NaN      19103    PA
# 24                       NaN      19106    PA
# 25                       NaN      19123    PA
# 26                       NaN      19107    PA
# 27                       NaN      19107    PA
# 28                       NaN      19104    PA
# 29                       NaN      19145    PA
# 30              Logan Square      19103    PA

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
